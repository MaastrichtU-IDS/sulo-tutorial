# %% [markdown]
# This is a notebook to setup the environment, explore an upper level ontology called SULO (Simplified Upper Level Ontology), and perform some automated reasoning, query, and visualization.

# %% [markdown]
# First, let's setup a virtual environment, and install the required libraries for the tutorial.

# %%
# !python -m venv .venv
# !source .venv/bin/activate
# !pip install --upgrade pip
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: pip in ./.venv/lib/python3.13/site-packages (26.0.1)
# Requirement already satisfied: ipykernel in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 1)) (7.2.0)
# Requirement already satisfied: owlready2 in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 2)) (0.50)
# Requirement already satisfied: graphviz in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 3)) (0.21)
# Requirement already satisfied: requests in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 4)) (2.33.0)
# Requirement already satisfied: comm>=0.1.1 in ./.venv/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 1)) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in ./.venv/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 1)) (9.12.0)
# Requirement already satisfied: jupyter-client>=8.8.0 in ./.venv/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 1)) (8.8.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in ./.venv/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 1)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 1)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in ./.venv/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: packaging>=22 in ./.venv/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 1)) (26.0)
# Requirement already satisfied: psutil>=5.7 in ./.venv/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 1)) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in ./.venv/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 1)) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in ./.venv/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 1)) (6.5.5)
# Requirement already satisfied: traitlets>=5.4.0 in ./.venv/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 1)) (5.14.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.13/site-packages (from requests->-r requirements.txt (line 4)) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.13/site-packages (from requests->-r requirements.txt (line 4)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in ./.venv/lib/python3.13/site-packages (from requests->-r requirements.txt (line 4)) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in ./.venv/lib/python3.13/site-packages (from requests->-r requirements.txt (line 4)) (2026.2.25)
# Requirement already satisfied: decorator>=5.1.0 in ./.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in ./.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in ./.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.19.2)
# Requirement already satisfied: pexpect>4.6 in ./.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in ./.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in ./.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.6.3)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./.venv/lib/python3.13/site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.8.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.13/site-packages (from jupyter-client>=8.8.0->ipykernel->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in ./.venv/lib/python3.13/site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel->-r requirements.txt (line 1)) (4.9.4)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.13/site-packages (from pexpect>4.6->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.8.0->ipykernel->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (3.0.1)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.2.3)

# %% [markdown]
# Now let's load the SULO ontology from it's location on the web and print out its base IRI.

# %%
from owlready2 import *
from lib.helpers import *
from graphviz import Digraph

# Load SULO (remote import)
sulo = get_ontology("https://w3id.org/sulo/sulo.owl").load()  # RDF/XML
print("Loaded SULO:", sulo.base_iri)
# Out:
# Loaded SULO: https://w3id.org/sulo/

# %% [markdown]
# Let's now visualize the class hierarchy in SULO using a functions defined in lib/helpers.py.

# %%
sulo_class_tree = get_color_tree(sulo)
print("SULO Class hierarchy")
display(sulo_class_tree)  # Class hierarchy
# Out:
# SULO Class hierarchy

# %%
print("SULO Property map")
sulo_property_map = onto_property_map(sulo)
display(sulo_property_map)    # Property domain-range map
# Out:
# SULO Property map

# %%
result = safe_call_reasoner(sulo)

print("SULO ontology after reasoning has", len(list(sulo.classes())), "classes")
print("SULO ontology after reasoning has", len(list(sulo.object_properties())), "object properties")
print("SULO ontology after reasoning has", len(list(sulo.data_properties())), "data properties")
print("SULO ontology after reasoning has", len(list(sulo.individuals())), "individuals")
print("SULO ontology has", len(result["inconsistent"]), "inconsistent classes")
for ic in result["inconsistent"]:
    print(" -", ic)
# Out:
# SULO ontology after reasoning has 17 classes
# SULO ontology after reasoning has 18 object properties
# SULO ontology after reasoning has 1 data properties
# SULO ontology after reasoning has 0 individuals
# SULO ontology has 0 inconsistent classes

# %%
# get the label for quantity
sulo.Quantity.label
# Out:
# [locstr('quantity', 'en')]

# %%
# query the SULO ontology for all subclasses of Quantity, excluding Quantity itself
print("SULO Quantity descendents:")
for cls in sulo.Quantity.descendants():
    if cls is not sulo.Quantity:
        print(" -", cls.name)
# Out:
# SULO Quantity descendents:
#  - Unit
#  - TimeInstant
#  - Time
#  - StartTime
#  - TimeInterval
#  - Duration
#  - EndTime

# %%
# get the ancestors of sulo.Quantity, excluding Quantity
print("SULO Quantity ancestors:")
for anc in sulo.Quantity.ancestors():
    if anc is not sulo.Quantity:
        print(" -", anc.name)
# Out:
# SULO Quantity ancestors:
#  - Thing
#  - Object
#  - Feature
#  - InformationObject
